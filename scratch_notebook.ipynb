# %%
from models.dataset_utils import IAMDataset2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 from models.dataset_utils import IAMDataset2
#
# File ~\PycharmProjects\ssl_wordspotting\models\dataset_utils.py:3, in <module>
#       1 import pathlib
# ----> 3 from torch.utils.data import Dataset, DataLoader
#       4 import os
#       5 from PIL import Image
#
# ModuleNotFoundError: No module named 'torch'

# %%
# !jupyter kernelspec list
# Out:
# Available kernels:
#   python3    C:\Users\Doc\anaconda3\share\jupyter\kernels\python3

# %%
import numpy as np
from numpy.random import randint

# %%
f = randint(1,3,3)
print(f)
# Out:
# [2 2 2]

# %%
from scipy.spatial.distance import pdist, squareform
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 from scipy.spatial.distance import pdist, squareform
#
# File ~\anaconda3\lib\site-packages\scipy\spatial\__init__.py:98, in <module>
#      96 from .kdtree import *
#      97 from .ckdtree import *
# ---> 98 from .qhull import *
#      99 from ._spherical_voronoi import SphericalVoronoi
#     100 from ._plotutils import *
#
# ImportError: DLL load failed while importing qhull: The specified module could not be found.
